# %% [markdown]
# # Mapping Malaysia’s AI Job Landscape: Insights from Web Scraping and Data Analysis

# %% [markdown]
# ## Introduction

# %% [markdown]
# The recent technology boom has brought the concept of an Artificial Intelligence (AI) enabled workforce to be not so not distant anymore -- it is unfolding in front of our eyes, coded line by line and built model by model. As AI carves its space across industries, Malaysia stands at a pivotal juncture: ready to either embrace transformation or risk being left behind.
#
# But where exactly are these AI opportunities emerging?
# Who is hiring, and what skills are most urgently needed?
# To answer these questions, I scraped live job postings from LinkedIn and turned the raw data into a map — a map of where Malaysia's AI future is in the midst of being built.

# %% [markdown]
# ## Methodology: Turning Scrapes into Stories

# %% [markdown]
# Behind the scenes, this project leveraged Python-based web scraping, targeting LinkedIn’s job posting APIs.
#
# From over 110 unique AI-related job ads, I was able to cautiously perform my own data manipulation:
# - Missing data (empty titles, companies) was dropped
# - Locations were standardized (Kuala Lumpur, Selangor, Penang, etc.)
# - Duplicate jobs were removed
# - Posting dates were categorized into "freshness bands" or
#
# Through this cleaning, I was able to capture, from a surface-level, a picture of Malaysia’s AI hiring landscape.

# %% [markdown]
# ## Insights: A Journey Across the Malaysian AI Market

# %% [markdown]
# ### 📍 Where the Opportunities Cluster: Geographic Hotspots
#
# If opportunity had a postcode, it would almost certainly belong to **Kuala Lumpur**.
# Kuala Lumpur remains the beating heart of AI hiring, trailed distantly by Selangor and Penang. As it is the capital city this doesn't come as a surprise. The capital has sustained a strong leadership position in the tech industry for a few decades now, only just competing with a reigniting market, in Selangor and Penang.

# %% [markdown]
# ![top_locations_plot.png](attachment:4cd69f50-95c9-45e9-9ac5-8478005c3d8c.png)

# %% [markdown]
# **Observation:**
#
# Kuala Lumpur accounts for more than 40% of all AI-related postings, reaffirming its role as Malaysia’s innovation engine. Selangor and Penang follow indicating a strong AI ecosystem being established in both the corporate technology parks and industry sectors. Johor remains relatively under represented, showcasing an opportunity for future allocation of resources for the state's development. A significant number in the 'Other' category suggests that there is some scattered demand outside of the main cities -- possibly startups being present in these areas.
#
# **Key Insight:**
#
# If you're someone looking for an AI role in this country, the numbers strongly point to Kuala Lumpur (KL) to be your most promising place to land a role!

# %% [markdown]
# ### 🧠 The DNA of AI Careers: Common Roles and Themes
#
# What defines an AI career in Malaysia today?
# A deep dive into job titles reveals a landscape dominated by Data Scientists, Machine Learning Engineers, and AI Product Managers.

# %% [markdown]
# ![top_10_AI_titles_pie.png](attachment:31724f8d-ecd8-4cf4-88ce-4321516353b6.png)

# %% [markdown]
# **Observation:**
#
# No single job title dominates the market — indicating healthy variety in roles (Engineer, Scientist, Manager, Developer). Even less common titles like "Strategy Champion" or "Product Strategy Lead" point toward non-traditional AI leadership roles emerging in the Malaysian markets.
#
# **Key Insight:**
#
# AI is not just for engineers — leadership and business strategic roles around AI are also rising. So to any students out there coming from a business or strategy background, this is proof that it is possible to break into the AI sector!

# %% [markdown]
# ![wordcloud.png](attachment:75c615be-055c-4e77-a862-11edaec83d98.png)

# %% [markdown]
# **Observation:**
#
# Visual dominance of "Manager," "Engineer," "Scientist," and "Product" — again reinforcing technical-business hybrid roles - show a that recruitment in this sector is very accepting of diverse range of academic backgrounds.
# Terms like "Analytics," "Strategy," "Developer," and "Machine Learning" stand out, showing a blend of engineering, decision-making, and analysis skills needed in order to land a role in the sector.
#
# **Key Insight:**
#
# Blending data engineering, AI modeling, and business strategy is key for career success.

# %% [markdown]
# ### 🏢 The Architects: Top Companies Shaping Malaysia’s AI Future
#
# A handful of companies act as the architects of Malaysia’s AI ecosystem.
# From tech giants to dynamic startups, these firms are writing the next chapters of Malaysia’s digital economy.

# %% [markdown]
# ![top_10_companies.png](attachment:e982839d-3476-4df7-abf5-aa11ff81f12c.png)

# %% [markdown]
# **Observation:**
#
# The distribution is fairly flat as most companies post similar numbers of AI jobs (around 2-4 each). No single "big fish" dominating the market like Google or Amazon — suggesting Malaysia’s AI sector is diverse and not monopolised. The level playing field also builds a foundation for the Malaysian AI industry to grow into one of the strongest sectors that could contribute alot to it's GDP.
#
# **Key Insight:**
#
# Candidates may have greater leverage negotiating offers, as no single employer holds overwhelming power. Maybe suggesting that going into this side of things wil bear greater salaries compared to other industries , especially in entry level jobs.

# %% [markdown]
# ### 🌎 The Geography of Innovation: Companies vs Locations
#
# It’s not just about who is hiring — it’s about where.
# The data heatmap reveals how companies spread their hiring across Malaysia, with Kuala Lumpur serving as the undisputed epicenter.

# %% [markdown]
# ![heatmap.png](attachment:b6f93ac5-83c9-4be5-9903-1afdb05b771d.png)

# %% [markdown]
# **Observations:**
#
# Companies like Mindrift and Outlier show a high concentration of postings in major hubs. Some companies like CoinMarketCap have presence across multiple cities — indicating remote or decentralized hiring. Arvato Systems and MoneyLion also show moderate distributed hiring — hinting at global teams or regional offices.
#
# **Key Insight:**
#
# Multinational firms may offer more flexibility across different Malaysian regions compared to local SMEs. The growing number of Datacentres in the region could also attract more technology MNCs to set up shop in the country as it has a strategically pivotal access point to the south china sea. MNCs could be using this as a way around the recent blowup of American tarrifs.

# %% [markdown]
# ### 📅 How Fresh Are These Opportunities?
#
# The pulse of the AI job market is gaining speed, on both an international and domestic scale.
# An overwhelming majority of postings are less than 30 days old — a clear sign of surging and ongoing demand. This could be the spark of a whole new industry or sector in the job market for Malaysia -- if the country is able to take advantage of this it move closer to a fully tech enabled workforce in the future

# %% [markdown]
# ![Distribution of Time Since Jobs Were Posted.png](attachment:22009fd4-c765-424e-8063-8c9fda685417.png)

# %% [markdown]
# ![Job Posting Age Categories.png](attachment:43ce3748-7b14-4d7b-b96e-e1b5570dcf35.png)

# %% [markdown]
# **Observation:**
#
# The majority of jobs were posted in the last 30 days, indicating a fresh and active hiring market. This is a strong sign of a growing demand for AI skills in the workforce - make sure you keep up!
#
# The "Unknown" category, while non-trivial, could imply posts without proper timestamps (maybe lower-quality listings).
#
# Older postings suggest some roles are harder to fill, possibly due to niche requirements or candidate shortages. There's a shprtage pf supply in labourers that have AI skills and this could be filled by new generations of the workforce, possibly fresh graduates coming back from abroad or universities in malaysia.
#
# **Insight:**
#
# For job seekers, focusing on recent postings will maximize chances of landing interviews quickly. And hopefully landing the job itself!

# %% [markdown]
# ## Reflections: What This Data Tells Us
#
# Malaysia’s AI hiring patterns reveal something deeper:
# AI is no longer just a "tech sector" phenomenon.
# It is infiltrating every layer — from banking and logistics to healthcare and manufacturing. This inference suggests that regardless of what sector you're in AI will boost your employability. In my opinion this is the case as AI skills will indeed improve efficiency and productivity of workers if they are trained to use it correctly and in a way that aligns with each company's goals, values and regulations.
#
# Moreover:
# - Kuala Lumpur’s dominance signals continued centralization of digital innovation in Malaysia.
# - The prevalence of leadership roles hints that companies are moving beyond experimentation toward serious AI integration strategies. Even large Malaysian banks have recently rolled out initiatives and strategies that use AI to maximise efficiency and minimise cost
# - The freshness of postings tells us this market is now indeed alive and moving quickly.

# %% [markdown]
# ## Conclusion: The Road Ahead
#
# Data doesn’t just describe the present, it gives us an insight about the future formulation of the workforce and how it will develop. Malaysia’s AI scene is gathering momentum, and opportunities are bound for those who can read these signals early and take action before the masses do. From aspiring data scientists to seasoned AI strategists, the door is wide open — but it won’t stay open forever. For policymakers, educators, and employers alike I would say, from what I understand:   **The time to nurture AI talent, build ecosystems, and invest in innovation is now.**

# %% [markdown]
# ## 🚀 A Final Thought
#
# This project shows that even with a simple scraper, a cleaned dataset with a minimal sample size, and a few graphs, we can map complex market dynamics. I would imagine that richer and deeper datasets, using a much larger sample size could reveal much more about the development of this sector and related roles in Malaysia and possibly even allow us to gauge where and when it would reach it's peak and who will gain most from it.
