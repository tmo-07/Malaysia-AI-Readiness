# %%
import requests 
from bs4 import BeautifulSoup 
import random 
import pandas as pd 
import time

# %%
title = "AI Demand in Malaysia" 
location = "Malaysia"

# %%
#for start in range(0, 250, 25):
list_url = "https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=ai&location=Malaysia&start=50" 
    
response = requests.get(list_url)   
    
list_data = response.text 
list_soup = BeautifulSoup(list_data, "html.parser") 
page_jobs = list_soup.find_all("li")

# %%
id_list = []

for job in page_jobs:
    base_card_div = job.find("div", {"class": "base-card"}) 
    job_id = base_card_div.get("data-entity-urn").split(":")[3]
    print(job_id)
    id_list.append(job_id)
# Out:
# 4158541216
# 4205775053
# 4217268007
# 4210655674
# 4180004698
# 4180646922
# 4212692917
# 4206448988
# 4186403060
# 4202014858

# %%
job_list = []

for job_id in id_list:
    job_url = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id}"
    job_response = requests.get(job_url)
    print(job_response.status_code)
    job_soup = BeautifulSoup(job_response.text, "html.parser")
    job_post = {}
    try:
        job_post["company_name"] = job_soup.find("a", {"class": "topcard__org-name-link topcard__flavor--black-link"}).text.strip()
    except: 
        job_post["company_name"] = None
    try:
        job_post["job_title"] = job_soup.find("h2", {"class": "top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title"}).text.strip()
    except:
        job_post["job_title"] = None 
    try:
        job_post["time_posted"] = job_soup.find("span", {"class": "posted-time-ago__text topcard__flavor--metadata"}).text.strip()
    except:
        job_post["time_posted"] = None
    try:
        job_post["location"] = job_soup.find("span", {"class": "topcard__flavor topcard__flavor--bullet"}).text.strip()
    except: 
        job_post["location"] = None

    
    job_list.append(job_post)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429

# %%
job_list
# Out:
# [{'company_name': 'Lenovo',
#   'job_title': 'Big Data Engineer',
#   'time_posted': None,
#   'location': 'Petaling Jaya, Selangor, Malaysia'},
#  {'company_name': 'Ryt Bank',
#   'job_title': 'Senior Business Intelligence Analyst',
#   'time_posted': '2 weeks ago',
#   'location': 'Greater Kuala Lumpur'},
#  {'company_name': 'CITAGLOBAL BERHAD',
#   'job_title': 'HEAD OF TECHNOLOGY & INNOVATION',
#   'time_posted': '1 day ago',
#   'location': 'Federal Territory of Kuala Lumpur, Malaysia'},
#  {'company_name': 'r3 Consultant',
#   'job_title': 'Product Specialist AI/ML',
#   'time_posted': '1 week ago',
#   'location': 'Cyberjaya, Selangor, Malaysia'},
#  {'company_name': 'Lenovo',
#   'job_title': 'Business Analyst- Product Lifecycle Management (PLM)',
#   'time_posted': '3 days ago',
#   'location': 'Petaling Jaya, Selangor, Malaysia'},
#  {'company_name': 'Novartis',
#   'job_title': 'Business Excellence & Execution Head',
#   'time_posted': None,
# ...

# %%
list_url1 = "https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=ai&location=Malaysia&start=25" 
    
response1 = requests.get(list_url1)   
    
list_data1 = response1.text 
list_soup1 = BeautifulSoup(list_data1, "html.parser") 
page_jobs1 = list_soup.find_all("li")

# %%
for job in page_jobs1:
    base_card_div = job.find("div", {"class": "base-card"}) 
    job_id1 = base_card_div.get("data-entity-urn").split(":")[3]
    print(job_id1)
    id_list.append(job_id1)
# Out:
# 4158541216
# 4205775053
# 4217268007
# 4210655674
# 4180004698
# 4180646922
# 4212692917
# 4206448988
# 4186403060
# 4202014858

# %%
id_list
# Out:
# ['4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
# ...

# %%
for job_id1 in id_list:
    job_url1 = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id1}"
    job_response1 = requests.get(job_url1)
    print(job_response1.status_code)
    job_soup1 = BeautifulSoup(job_response1.text, "html.parser")
    job_post1 = {}
    try:
        job_post1["company_name"] = job_soup1.find("a", {"class": "topcard__org-name-link topcard__flavor--black-link"}).text.strip()
    except: 
        job_post1["company_name"] = None
    try:
        job_post1["job_title"] = job_soup1.find("h2", {"class": "top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title"}).text.strip()
    except:
        job_post1["job_title"] = None 
    try:
        job_post1["time_posted"] = job_soup1.find("span", {"class": "posted-time-ago__text topcard__flavor--metadata"}).text.strip()
    except:
        job_post1["time_posted"] = None
    try:
        job_post1["location"] = job_soup1.find("span", {"class": "topcard__flavor topcard__flavor--bullet"}).text.strip()
    except: 
        job_post1["location"] = None

    
    job_list.append(job_post1)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 200
# 429
# 200
# 200
# 429
# 429
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 200
# 429
# 200

# %%
job_list
# Out:
# [{'company_name': 'Lenovo',
#   'job_title': 'Big Data Engineer',
#   'time_posted': None,
#   'location': 'Petaling Jaya, Selangor, Malaysia'},
#  {'company_name': 'Ryt Bank',
#   'job_title': 'Senior Business Intelligence Analyst',
#   'time_posted': '2 weeks ago',
#   'location': 'Greater Kuala Lumpur'},
#  {'company_name': 'CITAGLOBAL BERHAD',
#   'job_title': 'HEAD OF TECHNOLOGY & INNOVATION',
#   'time_posted': '1 day ago',
#   'location': 'Federal Territory of Kuala Lumpur, Malaysia'},
#  {'company_name': 'r3 Consultant',
#   'job_title': 'Product Specialist AI/ML',
#   'time_posted': '1 week ago',
#   'location': 'Cyberjaya, Selangor, Malaysia'},
#  {'company_name': 'Lenovo',
#   'job_title': 'Business Analyst- Product Lifecycle Management (PLM)',
#   'time_posted': '3 days ago',
#   'location': 'Petaling Jaya, Selangor, Malaysia'},
#  {'company_name': 'Novartis',
#   'job_title': 'Business Excellence & Execution Head',
#   'time_posted': None,
# ...

# %%
list_url2 = "https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=ai&location=Malaysia&start=75" 
    
response2 = requests.get(list_url2)   
    
list_data2 = response2.text 
list_soup2 = BeautifulSoup(list_data2, "html.parser") 
page_jobs2 = list_soup.find_all("li")

# %%
for job in page_jobs2:
    base_card_div = job.find("div", {"class": "base-card"}) 
    job_id2 = base_card_div.get("data-entity-urn").split(":")[3]
    print(job_id2)
    id_list.append(job_id2)
# Out:
# 4158541216
# 4205775053
# 4217268007
# 4210655674
# 4180004698
# 4180646922
# 4212692917
# 4206448988
# 4186403060
# 4202014858

# %%
id_list
# Out:
# ['4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
# ...

# %%
for job_id2 in id_list:
    job_url2 = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id2}"
    job_response2 = requests.get(job_url2)
    print(job_response2.status_code)
    job_soup2 = BeautifulSoup(job_response2.text, "html.parser")
    job_post2 = {}
    try:
        job_post2["company_name"] = job_soup2.find("a", {"class": "topcard__org-name-link topcard__flavor--black-link"}).text.strip()
    except: 
        job_post2["company_name"] = None
    try:
        job_post2["job_title"] = job_soup2.find("h2", {"class": "top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title"}).text.strip()
    except:
        job_post2["job_title"] = None 
    try:
        job_post2["time_posted"] = job_soup2.find("span", {"class": "posted-time-ago__text topcard__flavor--metadata"}).text.strip()
    except:
        job_post2["time_posted"] = None
    try:
        job_post2["location"] = job_soup2.find("span", {"class": "topcard__flavor topcard__flavor--bullet"}).text.strip()
    except: 
        job_post2["location"] = None

    
    job_list.append(job_post2)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429
# 429
# 200
# 200
# 429
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 200
# 429
# 429
# 200
# 429
# 200
# 200
# 200
# 200
# 200

# %%
job_list
# Out:
# [{'company_name': 'Lenovo',
#   'job_title': 'Big Data Engineer',
#   'time_posted': None,
#   'location': 'Petaling Jaya, Selangor, Malaysia'},
#  {'company_name': 'Ryt Bank',
#   'job_title': 'Senior Business Intelligence Analyst',
#   'time_posted': '2 weeks ago',
#   'location': 'Greater Kuala Lumpur'},
#  {'company_name': 'CITAGLOBAL BERHAD',
#   'job_title': 'HEAD OF TECHNOLOGY & INNOVATION',
#   'time_posted': '1 day ago',
#   'location': 'Federal Territory of Kuala Lumpur, Malaysia'},
#  {'company_name': 'r3 Consultant',
#   'job_title': 'Product Specialist AI/ML',
#   'time_posted': '1 week ago',
#   'location': 'Cyberjaya, Selangor, Malaysia'},
#  {'company_name': 'Lenovo',
#   'job_title': 'Business Analyst- Product Lifecycle Management (PLM)',
#   'time_posted': '3 days ago',
#   'location': 'Petaling Jaya, Selangor, Malaysia'},
#  {'company_name': 'Novartis',
#   'job_title': 'Business Excellence & Execution Head',
#   'time_posted': None,
# ...

# %%
list_url3 = "https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=ai&location=Malaysia&start=100" 
    
response3 = requests.get(list_url3)   
    
list_data3 = response3.text 
list_soup3 = BeautifulSoup(list_data3, "html.parser") 
page_jobs3 = list_soup.find_all("li")

# %%
for job in page_jobs3:
    base_card_div = job.find("div", {"class": "base-card"}) 
    job_id3 = base_card_div.get("data-entity-urn").split(":")[3]
    print(job_id3)
    id_list.append(job_id3)
# Out:
# 4158541216
# 4205775053
# 4217268007
# 4210655674
# 4180004698
# 4180646922
# 4212692917
# 4206448988
# 4186403060
# 4202014858

# %%
id_list
# Out:
# ['4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
#  '4186403060',
#  '4202014858',
#  '4158541216',
#  '4205775053',
#  '4217268007',
#  '4210655674',
#  '4180004698',
#  '4180646922',
#  '4212692917',
#  '4206448988',
# ...

# %%
for job_id3 in id_list:
    job_url3 = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id3}"
    job_response3 = requests.get(job_url3)
    print(job_response3.status_code)
    job_soup3 = BeautifulSoup(job_response3.text, "html.parser")
    job_post3 = {}
    try:
        job_post3["company_name"] = job_soup3.find("a", {"class": "topcard__org-name-link topcard__flavor--black-link"}).text.strip()
    except: 
        job_post3["company_name"] = None
    try:
        job_post3["job_title"] = job_soup3.find("h2", {"class": "top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title"}).text.strip()
    except:
        job_post3["job_title"] = None 
    try:
        job_post3["time_posted"] = job_soup3.find("span", {"class": "posted-time-ago__text topcard__flavor--metadata"}).text.strip()
    except:
        job_post3["time_posted"] = None
    try:
        job_post3["location"] = job_soup3.find("span", {"class": "topcard__flavor topcard__flavor--bullet"}).text.strip()
    except: 
        job_post3["location"] = None

    
    job_list.append(job_post3)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
job_list
# Out:
# [{'company_name': 'Lenovo',
#   'job_title': 'Big Data Engineer',
#   'time_posted': None,
#   'location': 'Petaling Jaya, Selangor, Malaysia'},
#  {'company_name': 'Ryt Bank',
#   'job_title': 'Senior Business Intelligence Analyst',
#   'time_posted': '2 weeks ago',
#   'location': 'Greater Kuala Lumpur'},
#  {'company_name': 'CITAGLOBAL BERHAD',
#   'job_title': 'HEAD OF TECHNOLOGY & INNOVATION',
#   'time_posted': '1 day ago',
#   'location': 'Federal Territory of Kuala Lumpur, Malaysia'},
#  {'company_name': 'r3 Consultant',
#   'job_title': 'Product Specialist AI/ML',
#   'time_posted': '1 week ago',
#   'location': 'Cyberjaya, Selangor, Malaysia'},
#  {'company_name': 'Lenovo',
#   'job_title': 'Business Analyst- Product Lifecycle Management (PLM)',
#   'time_posted': '3 days ago',
#   'location': 'Petaling Jaya, Selangor, Malaysia'},
#  {'company_name': 'Novartis',
#   'job_title': 'Business Excellence & Execution Head',
#   'time_posted': None,
# ...

# %%
list_url4 = "https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=ai&location=Malaysia&start=125" 
    
response4 = requests.get(list_url4)   
    
list_data4 = response4.text 
list_soup4 = BeautifulSoup(list_data4, "html.parser") 
page_jobs4 = list_soup.find_all("li")

# %%
for job in page_jobs4:
    base_card_div = job.find("div", {"class": "base-card"}) 
    job_id4 = base_card_div.get("data-entity-urn").split(":")[3]
    print(job_id4)
    id_list.append(job_id4)
# Out:
# 4158541216
# 4205775053
# 4217268007
# 4210655674
# 4180004698
# 4180646922
# 4212692917
# 4206448988
# 4186403060
# 4202014858

# %%
len(id_list)
# Out:
# 90

# %%
for job_id4 in id_list:
    job_url4 = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id4}"
    job_response4 = requests.get(job_url4)
    print(job_response4.status_code)
    job_soup4 = BeautifulSoup(job_response4.text, "html.parser")
    job_post4 = {}
    try:
        job_post4["company_name"] = job_soup4.find("a", {"class": "topcard__org-name-link topcard__flavor--black-link"}).text.strip()
    except: 
        job_post4["company_name"] = None
    try:
        job_post4["job_title"] = job_soup4.find("h2", {"class": "top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title"}).text.strip()
    except:
        job_post4["job_title"] = None 
    try:
        job_post4["time_posted"] = job_soup4.find("span", {"class": "posted-time-ago__text topcard__flavor--metadata"}).text.strip()
    except:
        job_post4["time_posted"] = None
    try:
        job_post4["location"] = job_soup4.find("span", {"class": "topcard__flavor topcard__flavor--bullet"}).text.strip()
    except: 
        job_post4["location"] = None

    
    job_list.append(job_post4)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
job_list
# Out:
# [{'company_name': 'Lenovo',
#   'job_title': 'Big Data Engineer',
#   'time_posted': None,
#   'location': 'Petaling Jaya, Selangor, Malaysia'},
#  {'company_name': 'Ryt Bank',
#   'job_title': 'Senior Business Intelligence Analyst',
#   'time_posted': '2 weeks ago',
#   'location': 'Greater Kuala Lumpur'},
#  {'company_name': 'CITAGLOBAL BERHAD',
#   'job_title': 'HEAD OF TECHNOLOGY & INNOVATION',
#   'time_posted': '1 day ago',
#   'location': 'Federal Territory of Kuala Lumpur, Malaysia'},
#  {'company_name': 'r3 Consultant',
#   'job_title': 'Product Specialist AI/ML',
#   'time_posted': '1 week ago',
#   'location': 'Cyberjaya, Selangor, Malaysia'},
#  {'company_name': 'Lenovo',
#   'job_title': 'Business Analyst- Product Lifecycle Management (PLM)',
#   'time_posted': '3 days ago',
#   'location': 'Petaling Jaya, Selangor, Malaysia'},
#  {'company_name': 'Novartis',
#   'job_title': 'Business Excellence & Execution Head',
#   'time_posted': None,
# ...

# %%
jobs_df = pd.DataFrame(job_list) 
jobs_df
# Out:
#           company_name                                          job_title  \
# 0               Lenovo                                  Big Data Engineer
# 1             Ryt Bank               Senior Business Intelligence Analyst
# 2    CITAGLOBAL BERHAD                    HEAD OF TECHNOLOGY & INNOVATION
# 3        r3 Consultant                           Product Specialist AI/ML
# 4               Lenovo  Business Analyst- Product Lifecycle Management...
# ..                 ...                                                ...
# 445               None                                               None
# 446               None                                               None
# 447               None                                               None
# 448               None                                               None
# 449               None                                               None
#
#      time_posted                                     location
# ...

# %%
# !mkdir -p ../data/raw

# %%
jobs_df.to_csv("../data/raw/linkedin_ai_jobs_malaysia.csv", index=False)
print("✅ Saved raw job data!")
# Out:
# ✅ Saved raw job data!

# %%
jobs_df = pd.read_csv("../data/raw/linkedin_ai_jobs_malaysia.csv")
print("✅ Data loaded!")
jobs_df.head()
# Out:
# ✅ Data loaded!
#         company_name                                          job_title  \
# 0             Lenovo                                  Big Data Engineer
# 1           Ryt Bank               Senior Business Intelligence Analyst
# 2  CITAGLOBAL BERHAD                    HEAD OF TECHNOLOGY & INNOVATION
# 3      r3 Consultant                           Product Specialist AI/ML
# 4             Lenovo  Business Analyst- Product Lifecycle Management...
#
#    time_posted                                     location
# 0          NaN            Petaling Jaya, Selangor, Malaysia
# 1  2 weeks ago                         Greater Kuala Lumpur
# 2    1 day ago  Federal Territory of Kuala Lumpur, Malaysia
# 3   1 week ago                Cyberjaya, Selangor, Malaysia
# 4   3 days ago            Petaling Jaya, Selangor, Malaysia

# %%
jobs_df.isnull().sum()
# Out:
# company_name    35
# job_title       35
# time_posted     93
# location        35
# dtype: int64

# %%
jobs_df = jobs_df.dropna(subset=["company_name", "job_title", "location"])
print("✅ Dropped rows with missing critical fields.")
# Out:
# ✅ Dropped rows with missing critical fields.

# %%
jobs_df["time_posted"] = jobs_df["time_posted"].fillna("Not specified")
print("✅ Filled missing time_posted.")
# Out:
# ✅ Filled missing time_posted.

# %%
jobs_df.isnull().sum()
# Out:
# company_name    0
# job_title       0
# time_posted     0
# location        0
# dtype: int64

# %%
jobs_df = jobs_df.drop_duplicates()
print("✅ Dropped duplicates if any.")
# Out:
# ✅ Dropped duplicates if any.

# %%
# !mkdir -p ../data/processed

# %%
jobs_df.to_csv("../data/processed/linkedin_ai_jobs_malaysia_clean.csv", index=False)
print("Saved cleaned job data to processed folder!")
# Out:
# Saved cleaned job data to processed folder!

# %%
import os
os.listdir("../data/processed")
# Out:
# ['linkedin_ai_jobs_malaysia_clean.csv']

# %%
print(f"Total jobs scraped: {len(jobs_df)}")
# Out:
# Total jobs scraped: 12

# %%
jobs_df
# Out:
#          company_name                                          job_title  \
# 0              Lenovo                                  Big Data Engineer
# 1            Ryt Bank               Senior Business Intelligence Analyst
# 2   CITAGLOBAL BERHAD                    HEAD OF TECHNOLOGY & INNOVATION
# 3       r3 Consultant                           Product Specialist AI/ML
# 4              Lenovo  Business Analyst- Product Lifecycle Management...
# 5            Novartis               Business Excellence & Execution Head
# 6                Grab  Intern - Data Scientist (Analytics) - Country ...
# 7           AEON Bank                           Data Analyst, Operations
# 8     SCIENCETECH INC               Internship For Robotic AI Stem Maker
# 19             MRANTI                 Head, Intelligent Operation Centre
#
#       time_posted                                           location
# 0   Not specified                  Petaling Jaya, Selangor, Malaysia
# ...

# %%
jobs_df = pd.read_csv("../data/raw/linkedin_ai_jobs_malaysia.csv")
print(jobs_df.shape)
# Out:
# (150, 4)

# %%
jobs_df.head()
# Out:
#         company_name                                          job_title  \
# 0             Lenovo                                  Big Data Engineer
# 1           Ryt Bank               Senior Business Intelligence Analyst
# 2  CITAGLOBAL BERHAD                    HEAD OF TECHNOLOGY & INNOVATION
# 3      r3 Consultant                           Product Specialist AI/ML
# 4             Lenovo  Business Analyst- Product Lifecycle Management...
#
#    time_posted                                     location
# 0          NaN            Petaling Jaya, Selangor, Malaysia
# 1  2 weeks ago                         Greater Kuala Lumpur
# 2    1 day ago  Federal Territory of Kuala Lumpur, Malaysia
# 3   1 week ago                Cyberjaya, Selangor, Malaysia
# 4   3 days ago            Petaling Jaya, Selangor, Malaysia

# %%
jobs_df["company_name"] = jobs_df["company_name"].fillna("Not Specified")
jobs_df["job_title"] = jobs_df["job_title"].fillna("Not Specified")
jobs_df["location"] = jobs_df["location"].fillna("Not Specified")
jobs_df["time_posted"] = jobs_df["time_posted"].fillna("Not Specified")

# %%
jobs_df = jobs_df.drop_duplicates()

# %%
print(f"Total cleaned jobs: {len(jobs_df)}")
jobs_df.head()
# Out:
# Total cleaned jobs: 11
#         company_name                                          job_title  \
# 0             Lenovo                                  Big Data Engineer
# 1           Ryt Bank               Senior Business Intelligence Analyst
# 2  CITAGLOBAL BERHAD                    HEAD OF TECHNOLOGY & INNOVATION
# 3      r3 Consultant                           Product Specialist AI/ML
# 4             Lenovo  Business Analyst- Product Lifecycle Management...
#
#      time_posted                                     location
# 0  Not Specified            Petaling Jaya, Selangor, Malaysia
# 1    2 weeks ago                         Greater Kuala Lumpur
# 2      1 day ago  Federal Territory of Kuala Lumpur, Malaysia
# 3     1 week ago                Cyberjaya, Selangor, Malaysia
# 4     3 days ago            Petaling Jaya, Selangor, Malaysia

# %%
list_url5 = "https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=ai&location=Malaysia&start=150" 
    
response5 = requests.get(list_url5)   
    
list_data5 = response5.text 
list_soup5 = BeautifulSoup(list_data5, "html.parser") 
page_jobs5 = list_soup.find_all("li")

# %%
for job in page_jobs:
    base_card_div = job.find("div", {"class": "base-card"}) 
    job_id5 = base_card_div.get("data-entity-urn").split(":")[3]
    print(job_id4)
    id_list.append(job_id4)

# %%
response.text
# Out:
# '<!DOCTYPE html>\n\n      <li>\n        \n    \n\n    \n    \n    \n      <div class="base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card" data-entity-urn="urn:li:jobPosting:4212027490" data-impression-id="jobs-search-result-0" data-reference-id="ufRIzfVN5C9g+E7jUM/S7Q==" data-tracking-id="VUcbab7OeYzdcpd/4fkO8A==" data-column="1" data-row="26">\n        \n\n        <a class="base-card__full-link absolute top-0 right-0 bottom-0 left-0 p-0 z-[2]" href="https://my.linkedin.com/jobs/view/junior-senior-data-scientist-artificial-intelligence-at-tm-research-development-4212027490?position=1&amp;pageNum=2&amp;refId=ufRIzfVN5C9g%2BE7jUM%2FS7Q%3D%3D&amp;trackingId=VUcbab7OeYzdcpd%2F4fkO8A%3D%3D" data-tracking-control-name="public_jobs_jserp-result_search-card" data-tracking-client-ingraph data-tracking-will-navigate>\n          \n          <span class="sr-only">\n              \n        \n        Junior/Senior
# ...

# %%
job_id = "4176439332" 
job_url = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id}"
jobs_response = requests.get(job_url)

# %%
jobs_response
# Out:
# <Response [200]>

# %%
jobs_response.text
# Out:
# '\n\n    \n<!---->    \n    \n\n    \n    <section class="top-card-layout container-lined overflow-hidden babybear:rounded-[0px]">\n        \n      \n\n      <div class="top-card-layout__card relative p-2 papabear:p-details-container-padding">\n            \n        \n      <a href="https://sg.linkedin.com/company/azeus-systems-ltd?trk=public_jobs_topcard_logo" target="_self" data-tracking-control-name="public_jobs_topcard_logo" data-tracking-will-navigate>\n        \n          \n      <img class="artdeco-entity-image artdeco-entity-image--square-5\n          " data-delayed-url="https://media.licdn.com/dms/image/v2/C560BAQEqxf5vbX98WA/company-logo_100_100/company-logo_100_100/0/1631377534271?e=2147483647&amp;v=beta&amp;t=Xin8wXF9R84wFeJ-bzaHXCEaOIY2dMCZrRZ6QJBPdD4" data-ghost-classes="artdeco-entity-image--ghost" data-ghost-url="https://static.licdn.com/aero-v1/sc/h/aajlclc14rr2scznz5qm2rj9u" alt="Azeus Systems Limited">\n  \n        \n      </a>\n  \n      \n\n          <div class="
# ...
